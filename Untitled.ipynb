# %%
import os

# %%
os.getcwd()
# Out:
# 'E:\\hariprasath\\My work 2026\\LEARN ROADMAP\\PYTHON\\Projects\\fileOrganizer'

# %%
path = r"E:\hariprasath\My work 2026\LEARN ROADMAP\PYTHON\Projects\sample"

# %%
files= os.listdir(path)

# %%
files[0]
# Out:
# '0th Review.pptx'

# %%
os.path.splitext(files[0])
# Out:
# ('0th Review', '.pptx')

# %%
data = {

    # Images
    '.jpg': 'Images',
    '.png': 'Images',

    # Text / Documents
    '.txt': 'Text',
    '.pdf': 'Documents',
    '.docx': 'Documents',
    '.xlsx': 'Documents',
    '.pptx': 'Documents',

    # Documentation
    '.md': 'Documentation',
    '.rst': 'Documentation',

    # Audio
    '.mp3': 'Audio',
    '.wav': 'Audio',

    # Videos
    '.mp4': 'Videos',
    '.avi': 'Videos',
    '.mkv': 'Videos',

    # Archives / Compressed
    '.zip': 'Archives',
    '.rar': 'Archives',
    '.7z': 'Archives',
    '.tar': 'Archives',
    '.gz': 'Archives',
    '.bz2': 'Archives',

    # Executables
    '.exe': 'Executables',
    '.msi': 'Executables',

    # Programming Code
    '.py': 'Code',
    '.java': 'Code',
    '.cpp': 'Code',
    '.html': 'Code',
    '.css': 'Code',
    '.js': 'Code',

    # Data Files
    '.json': 'Data',
    '.csv': 'Data',
    '.xml': 'Data',

    # Design Files
    '.psd': 'Design Files',
    '.ai': 'Design Files',
    '.indd': 'Design Files',
    '.svg': 'Design Files',
    '.eps': 'Design Files',

    # Fonts
    '.ttf': 'Fonts',
    '.otf': 'Fonts',
    '.woff': 'Fonts',
    '.woff2': 'Fonts',
    '.eot': 'Fonts',

    # Logs / Temporary / Backup
    '.log': 'Logs',
    '.bak': 'Backups',
    '.tmp': 'Temporary',

    # Disk Images
    '.iso': 'Disk Images',
    '.dmg': 'Disk Images',
}

# %%
s=files[:2]

# %%
for file in s:
    if not os.path.isfile(os.path.join(path,file)):
        continue
    
    name,ext = os.path.splitext(file)
    ext = ext.lower()
    if ext in data:
        nfolder = data[ext] 
    else:
        nfolder = 'others'
    if os.path.exists(os.path.join(path,nfolder)):
        print(os.path.join(path,nfolder))
    else:
        os.mkdir(os.path.join(path,nfolder))
        print('making dir',nfolder)
    shutil.move(os.path.join(path,file), os.path.join(path,nfolder,file))
# Out:
# making dir Documents
# making dir Documents
